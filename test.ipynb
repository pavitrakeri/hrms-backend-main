# %%
import bcrypt
print(bcrypt.hashpw(b"Admin@c2s", bcrypt.gensalt()).decode())
# Out:
# $2b$12$igB/s2Pt8hvUkcwF31sNG.3tHCIW6d.Bnxp7NtA9bxnsRhmOq8FI2

# %%
# !pip install bcrypt
# Out:
# ...
#   Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
